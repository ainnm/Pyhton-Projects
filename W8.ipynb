# %%
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# test1

# %%
import csv
with open('students.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['Name', 'Age', 'Grade']
# ['Alice', '21', 'A']
# ['Bob', '22', 'F']
# ['Charlie', '18', 'B']
# ['David', '21', 'A']
# ['Eve', '20', 'A']
# ['Fiona', '18', 'C']
# ['George', '19', 'A']
# ['Hannah', '20', 'C']
# ['Isla', '22', 'A']
# ['Jack', '21', 'B']
# ['Alice', '20', 'C']
# ['Bob', '20', 'C']
# ['Charlie', '18', 'C']
# ['David', '20', 'A']
# ['Eve', '21', 'B']
# ['Fiona', '19', 'C']
# ['George', '18', 'F']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '18', 'F']
# ['Bob', '18', 'F']
# ['Charlie', '18', 'C']
# ['David', '18', 'F']
# ['Eve', '20', 'B']
# ['Fiona', '19', 'B']
# ['George', '21', 'D']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '19', 'B']
# ['Bob', '20', 'B']
# ['Charlie', '22', 'D']
# ['David', '20', 'C']
# ['Eve', '19', 'A']
# ['Fiona', '20', 'F']
# ['George', '21', 'F']
# ['Hannah', '22', 'F']
# ['Isla', '21', 'F']
# ['Jack', '19', 'F']
# ['Alice', '20', 'C']
# ['Bob', '22', 'F']
# ...

# %%
import csv
with open('students.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row[0]) #dr use 'Name' type of str, why i cant use? but its okay
# Out:
# Name
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack

# %%
with open('output.txt', 'w') as file:
    file.write("Hello, Python!")
    file.write("\nHello, Python!")
    for i in range(0,20) :
        file.write("\n" + str(i))

# %%
import json
data = {'name': 'Alice', 'age': 30}
with open('output.json', 'w') as file:
    json.dump(data, file)

# %%
import csv
with open('output.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Alice', 30])

# %%
import requests
api_url = "https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data = response.json()

for state in malaysia_state_data:
    print(f"State: {state['state']}, Capital: {state['capital']}, Population: {state['population']}")
# Out:
# State: Johor, Capital: Johor Bahru, Population: 3794000
# State: Kedah, Capital: Alor Setar, Population: 2194100
# State: Kelantan, Capital: Kota Bharu, Population: 1928800
# State: Malacca, Capital: Malacca City, Population: 937500
# State: Negeri Sembilan, Capital: Seremban, Population: 1129100
# State: Pahang, Capital: Kuantan, Population: 1684600
# State: Penang, Capital: George Town, Population: 1774400
# State: Perak, Capital: Ipoh, Population: 2508900
# State: Perlis, Capital: Kangar, Population: 255400
# State: Sabah, Capital: Kota Kinabalu, Population: 3833000
# State: Sarawak, Capital: Kuching, Population: 2822200
# State: Selangor, Capital: Shah Alam, Population: 6555400
# State: Terengganu, Capital: Kuala Terengganu, Population: 1275100
# State: Kuala Lumpur, Capital: Kuala Lumpur, Population: 1746600
# State: Labuan, Capital: Victoria, Population: 100100
# State: Putrajaya, Capital: Putrajaya, Population: 116100

# %%
import requests
api_url = "https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data = response.json()

for state in malaysia_state_data:
    print(f"State: {state['capital']}, Capital: {state['capital']}, Population: {state['population']}")
# Out:
# State: Johor Bahru, Capital: Johor Bahru, Population: 3794000
# State: Alor Setar, Capital: Alor Setar, Population: 2194100
# State: Kota Bharu, Capital: Kota Bharu, Population: 1928800
# State: Malacca City, Capital: Malacca City, Population: 937500
# State: Seremban, Capital: Seremban, Population: 1129100
# State: Kuantan, Capital: Kuantan, Population: 1684600
# State: George Town, Capital: George Town, Population: 1774400
# State: Ipoh, Capital: Ipoh, Population: 2508900
# State: Kangar, Capital: Kangar, Population: 255400
# State: Kota Kinabalu, Capital: Kota Kinabalu, Population: 3833000
# State: Kuching, Capital: Kuching, Population: 2822200
# State: Shah Alam, Capital: Shah Alam, Population: 6555400
# State: Kuala Terengganu, Capital: Kuala Terengganu, Population: 1275100
# State: Kuala Lumpur, Capital: Kuala Lumpur, Population: 1746600
# State: Victoria, Capital: Victoria, Population: 100100
# State: Putrajaya, Capital: Putrajaya, Population: 116100

# %%
import requests

api_url = "https://api.open-meteo.com/v1/forecast?latitude=2.5&longitude=112.5&hourly=temperature_2m&timezone=Asia%2FSingapore&forecast_days=1"
response = requests.get(api_url)

try:
    response.raise_for_status()  # Check for errors in the response
    hourly_temperature_data = response.json()['hourly']['temperature_2m']
    
    for entry in hourly_temperature_data:
        hour = input['timestamp_local']
        temperature = input['value']
        print(f"Hourly: {hour}, Temperature: {temperature}°C")

except requests.exceptions.HTTPError as errh:
    print(f"HTTP Error: {errh}")
except requests.exceptions.ConnectionError as errc:
    print(f"Error Connecting: {errc}")
except requests.exceptions.Timeout as errt:
    print(f"Timeout Error: {errt}")
except requests.exceptions.RequestException as err:
    print(f"Request Exception: {err}")
except KeyError as ke:
    print(f"KeyError: {ke}")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...
